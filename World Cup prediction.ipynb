# %%
#Import Libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
#Import datasets
matches = pd.read_csv('wc_matches.csv')
forecast = pd.read_csv('wc_forecasts.csv')

# %% [markdown]
# Things i need for prediction
# SPI of both teams
# sim_wins
# sim_ties
# sim_losses
# goals scored
# make finals

# %%
matches
# Out:
#           date  league_id          league         team1         team2   spi1  \
# 0   2022-11-20       1908  FIFA World Cup         Qatar       Ecuador  51.00
# 1   2022-11-21       1908  FIFA World Cup       England          Iran  85.96
# 2   2022-11-21       1908  FIFA World Cup       Senegal   Netherlands  73.84
# 3   2022-11-21       1908  FIFA World Cup           USA         Wales  74.83
# 4   2022-11-22       1908  FIFA World Cup     Argentina  Saudi Arabia  87.21
# 5   2022-11-22       1908  FIFA World Cup       Denmark       Tunisia  80.02
# 6   2022-11-22       1908  FIFA World Cup        Mexico        Poland  74.30
# 7   2022-11-22       1908  FIFA World Cup        France     Australia  87.71
# 8   2022-11-23       1908  FIFA World Cup       Morocco       Croatia  75.62
# 9   2022-11-23       1908  FIFA World Cup       Germany         Japan  88.77
# 10  2022-11-23       1908  FIFA World Cup         Spain    Costa Rica  89.51
# ...

# %%
forecast.head()
# Out:
#         forecast_timestamp       team group       spi  global_o  global_d  \
# 0  2022-11-30 21:00:41 UTC     Brazil     G  93.48139   3.06210   0.23656
# 1  2022-11-30 21:00:41 UTC      Spain     E  90.62031   2.84092   0.33577
# 2  2022-11-30 21:00:41 UTC  Argentina     C  87.98006   2.61284   0.38151
# 3  2022-11-30 21:00:41 UTC     France     D  88.57378   2.83760   0.46033
# 4  2022-11-30 21:00:41 UTC    England     B  86.96946   2.62701   0.44455
#
#    sim_wins  sim_ties  sim_losses  sim_goal_diff  ...  group_1  group_2  \
# 0   2.81069   0.15361     0.03570        4.93864  ...  0.99587  0.00413
# 1   1.61182   1.24899     0.13919        8.04129  ...  0.84834  0.14309
# 2   2.00000   0.00000     1.00000        3.00000  ...  1.00000  0.00000
# 3   2.00000   0.00000     1.00000        3.00000  ...  1.00000  0.00000
# 4   2.00000   1.00000     0.00000        7.00000  ...  1.00000  0.00000
#
#    group_3  group_4  make_round_of_16  make_quarters  make_semis  make_final  \
# ...

# %%
forecast.drop(columns=['group','forecast_timestamp', 'timestamp','global_o','global_d','group_1','group_2','group_3','group_4','make_round_of_16','make_quarters','make_semis','make_final']).head()
# Out:
#         team       spi  sim_wins  sim_ties  sim_losses  sim_goal_diff  \
# 0     Brazil  93.48139   2.81069   0.15361     0.03570        4.93864
# 1      Spain  90.62031   1.61182   1.24899     0.13919        8.04129
# 2  Argentina  87.98006   2.00000   0.00000     1.00000        3.00000
# 3     France  88.57378   2.00000   0.00000     1.00000        3.00000
# 4    England  86.96946   2.00000   1.00000     0.00000        7.00000
#
#    goals_scored  goals_against  win_league
# 0       5.25378        0.31514     0.24769
# 1       9.75271        1.71142     0.13230
# 2       5.00000        2.00000     0.11649
# 3       6.00000        3.00000     0.11311
# 4       9.00000        2.00000     0.08616

# %%
forecast
# Out:
#           spi  global_o  global_d  sim_wins  sim_ties  sim_losses  \
# 0    93.48139   3.06210   0.23656   2.81069   0.15361     0.03570
# 1    90.62031   2.84092   0.33577   1.61182   1.24899     0.13919
# 2    87.98006   2.61284   0.38151   2.00000   0.00000     1.00000
# 3    88.57378   2.83760   0.46033   2.00000   0.00000     1.00000
# 4    86.96946   2.62701   0.44455   2.00000   1.00000     0.00000
# ..        ...       ...       ...       ...       ...         ...
# 123  56.86592   1.50018   0.99118   0.59721   0.79021     1.61258
# 124  60.83178   1.59388   0.91112   0.55148   0.79247     1.65605
# 125  51.00223   1.57111   1.31642   0.56555   0.68681     1.74764
# 126  58.62702   1.43347   0.85806   0.46730   0.80877     1.72393
# 127  55.45518   1.39816   0.95388   0.29847   0.61279     2.08874
#
#      sim_goal_diff  goals_scored  goals_against  group_1  ...  team_Wales  \
# 0          4.93864       5.25378        0.31514  0.99587  ...           0
# ...

# %%
# Input and Output data

X = forecast.drop(columns=['win_league'])
y = forecast["win_league"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Modelling and predictions
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X,y)



prediction = model.predict(X_test)
prediction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [64], in <cell line: 3>()
#       1 #Modelling and predictions
#       2 model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
# ----> 3 model.fit(X,y)
#       7 prediction = model.predict(X_test)
#       8 prediction
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     327     y = np.reshape(y, (-1, 1))
#     329 self.n_outputs_ = y.shape[1]
# --> 331 y, expanded_class_weight = self._validate_y_class_weight(y)
#     333 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#     334     y = np.ascontiguousarray(y, dtype=DOUBLE)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:559, in ForestClassifier._validate_y_class_weight(self, y)
#     558 def _validate_y_class_weight(self, y):
# ...

# %%
output = str(X)
